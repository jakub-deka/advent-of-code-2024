# %%
from dataclasses import dataclass
from typing import Callable
import operator

# Define allowed operations
AND = operator.and_
OR = operator.or_
XOR = operator.xor

ALLOWED_OPERATIONS = {AND, OR, XOR}


@dataclass
class Gate:
    a: str
    b: str
    op: Callable[[bool, bool], bool]
    output: str

    shared_values = {}

    def __post_init__(self):
        if self.op not in ALLOWED_OPERATIONS:
            raise ValueError("Operation must be AND, OR, or XOR")

    def run(self):
        if self.a not in Gate.shared_values or self.b not in Gate.shared_values:
            raise ValueError(f"Gate attributes are not populated.")
        if self.output in Gate.shared_values:
            return
        a = Gate.shared_values.get(self.a)
        b = Gate.shared_values.get(self.b)
        Gate.shared_values[self.output] = int(self.op(a, b))

    def can_be_executed(self):
        if (
            self.a in Gate.shared_values
            and self.b in Gate.shared_values
            and self.output not in Gate.shared_values
        ):
            return True
        else:
            return False

    @staticmethod
    def print_output(designator: str = "z"):
        res = {k: v for k, v in Gate.shared_values.items() if k.startswith(designator)}
        res = dict(sorted(res.items(), key=lambda x: x[0], reverse=True))
        res = "".join([str(v) for _, v in res.items()])
        return res

    @staticmethod
    def print_int_output(designator: str = "z"):
        return int(Gate.print_output(designator), 2)

    @staticmethod
    def reset_shared_values():
        Gate.shared_values = {}


def crate_gate(a: str, b: str, op: str, output: str) -> Gate:
    ALLOWED_OPERATIONS = {"AND": AND, "OR": OR, "XOR": XOR}

    op_func = ALLOWED_OPERATIONS.get(op.upper())
    if op_func is None:
        raise ValueError(f"Invalid operation: {op}")

    return Gate(a, b, op_func, output)


def read_file(path):
    res = open(path, "r").readlines()
    res = [x.strip() for x in res]
    gates = []
    Gate.reset_shared_values()

    part = 1
    for l in res:
        if l == "":
            part += 1
        elif part == 1:
            l = l.split(":")
            Gate.shared_values[l[0]] = int(l[1])
        elif part == 2:
            l = [x.strip() for x in l.split("->")]
            ops = l[0].split(" ")
            gates.append(crate_gate(ops[0], ops[2], ops[1], l[1]))

    return gates

# %%
gates = read_file("example2")

while any(g.can_be_executed() for g in gates):
    for g in gates:
        if g.can_be_executed():
            g.run()

x = Gate.print_output("x")
y = Gate.print_output("y")
z = Gate.print_output("z")
print(f"x={x}  y={y}  z={z}")
# Out:
# x=101010  y=101100  z=101000

# %%
gates = read_file("input")
for g in gates:
    if g.can_be_executed():
        print(g)
# Out:
# Gate(a='x00', b='y00', op=<built-in function and_>, output='wrs')
# Gate(a='y35', b='x35', op=<built-in function xor>, output='cbq')
# Gate(a='y19', b='x19', op=<built-in function xor>, output='sdc')
# Gate(a='x01', b='y01', op=<built-in function and_>, output='rkd')
# Gate(a='x32', b='y32', op=<built-in function xor>, output='wrh')
# Gate(a='y44', b='x44', op=<built-in function and_>, output='nkv')
# Gate(a='y32', b='x32', op=<built-in function and_>, output='qrk')
# Gate(a='x08', b='y08', op=<built-in function and_>, output='fqc')
# Gate(a='x44', b='y44', op=<built-in function xor>, output='nbf')
# Gate(a='y02', b='x02', op=<built-in function and_>, output='hjh')
# Gate(a='y13', b='x13', op=<built-in function and_>, output='njs')
# Gate(a='x27', b='y27', op=<built-in function xor>, output='ppk')
# Gate(a='x09', b='y09', op=<built-in function and_>, output='bjj')
# Gate(a='y04', b='x04', op=<built-in function xor>, output='jth')
# Gate(a='x11', b='y11', op=<built-in function and_>, output='rrr')
# Gate(a='y12', b='x12', op=<built-in function xor>, output='fqr')
# Gate(a='x03', b='y03', op=<built-in function xor>, output='fph')
# Gate(a='y08', b='x08', op=<built-in function xor>, output='gjp')
# Gate(a='y19', b='x19', op=<built-in function and_>, output='kdt')
# Gate(a='y14', b='x14', op=<built-in function xor>, output='khg')
# Gate(a='x42', b='y42', op=<built-in function xor>, output='hfh')
# Gate(a='y16', b='x16', op=<built-in function and_>, output='ngh')
# Gate(a='x41', b='y41', op=<built-in function and_>, output='mtm')
# Gate(a='y04', b='x04', op=<built-in function and_>, output='qgm')
# Gate(a='y06', b='x06', op=<built-in function xor>, output='bmt')
# Gate(a='x07', b='y07', op=<built-in function xor>, output='qcb')
# Gate(a='x37', b='y37', op=<built-in function and_>, output='brw')
# Gate(a='x15', b='y15', op=<built-in function and_>, output='fjp')
# Gate(a='x24', b='y24', op=<built-in function and_>, output='cjj')
# Gate(a='y12', b='x12', op=<built-in function and_>, output='bsn')
# Gate(a='y27', b='x27', op=<built-in function and_>, output='kpd')
# Gate(a='x23', b='y23', op=<built-in function xor>, output='pjg')
# Gate(a='x05', b='y05', op=<built-in function and_>, output='z05')
# Gate(a='x17', b='y17', op=<built-in function xor>, output='csp')
# Gate(a='x43', b='y43', op=<built-in function and_>, output='vcb')
# Gate(a='x18', b='y18', op=<built-in function xor>, output='pvq')
# Gate(a='x37', b='y37', op=<built-in function xor>, output='cwm')
# Gate(a='x33', b='y33', op=<built-in function xor>, output='nwp')
# Gate(a='x35', b='y35', op=<built-in function and_>, output='fhw')
# Gate(a='x42', b='y42', op=<built-in function and_>, output='nwf')
# Gate(a='y25', b='x25', op=<built-in function xor>, output='wvk')
# Gate(a='x07', b='y07', op=<built-in function and_>, output='bqv')
# Gate(a='x38', b='y38', op=<built-in function xor>, output='pmd')
# Gate(a='y39', b='x39', op=<built-in function xor>, output='wtf')
# Gate(a='x26', b='y26', op=<built-in function and_>, output='jgh')
# Gate(a='x05', b='y05', op=<built-in function xor>, output='vtn')
# Gate(a='y16', b='x16', op=<built-in function xor>, output='rhc')
# Gate(a='x29', b='y29', op=<built-in function xor>, output='dpt')
# Gate(a='y21', b='x21', op=<built-in function and_>, output='dvg')
# Gate(a='y40', b='x40', op=<built-in function and_>, output='rsb')
# Gate(a='x43', b='y43', op=<built-in function xor>, output='jjw')
# Gate(a='x36', b='y36', op=<built-in function xor>, output='knv')
# Gate(a='y40', b='x40', op=<built-in function xor>, output='hnk')
# Gate(a='x09', b='y09', op=<built-in function xor>, output='wmk')
# Gate(a='x30', b='y30', op=<built-in function xor>, output='brt')
# Gate(a='y38', b='x38', op=<built-in function and_>, output='cgh')
# Gate(a='x28', b='y28', op=<built-in function xor>, output='qhs')
# Gate(a='x20', b='y20', op=<built-in function xor>, output='nmf')
# Gate(a='y22', b='x22', op=<built-in function and_>, output='pfs')
# Gate(a='y15', b='x15', op=<built-in function xor>, output='wjn')
# Gate(a='x11', b='y11', op=<built-in function xor>, output='tdd')
# Gate(a='x31', b='y31', op=<built-in function and_>, output='bbw')
# Gate(a='x39', b='y39', op=<built-in function and_>, output='nwb')
# Gate(a='y10', b='x10', op=<built-in function and_>, output='kwk')
# Gate(a='y01', b='x01', op=<built-in function xor>, output='wmq')
# Gate(a='x22', b='y22', op=<built-in function xor>, output='kmw')
# Gate(a='x31', b='y31', op=<built-in function xor>, output='fjq')
# Gate(a='y29', b='x29', op=<built-in function and_>, output='tpn')
# Gate(a='x18', b='y18', op=<built-in function and_>, output='sjc')
# Gate(a='x41', b='y41', op=<built-in function xor>, output='jpf')
# Gate(a='y24', b='x24', op=<built-in function xor>, output='dcr')
# Gate(a='y28', b='x28', op=<built-in function and_>, output='jfh')
# Gate(a='x06', b='y06', op=<built-in function and_>, output='rcg')
# Gate(a='x34', b='y34', op=<built-in function and_>, output='jmk')
# Gate(a='y00', b='x00', op=<built-in function xor>, output='z00')
# Gate(a='y20', b='x20', op=<built-in function and_>, output='mkq')
# Gate(a='x02', b='y02', op=<built-in function xor>, output='ssd')
# Gate(a='y33', b='x33', op=<built-in function and_>, output='qdm')
# Gate(a='y14', b='x14', op=<built-in function and_>, output='mck')
# Gate(a='x30', b='y30', op=<built-in function and_>, output='fnw')
# Gate(a='x13', b='y13', op=<built-in function xor>, output='whw')
# Gate(a='y17', b='x17', op=<built-in function and_>, output='rds')
# Gate(a='x34', b='y34', op=<built-in function xor>, output='chk')
# Gate(a='x03', b='y03', op=<built-in function and_>, output='wpn')
# Gate(a='x10', b='y10', op=<built-in function xor>, output='vdr')
# Gate(a='y23', b='x23', op=<built-in function and_>, output='gnj')
# Gate(a='y36', b='x36', op=<built-in function and_>, output='hhh')
# Gate(a='x26', b='y26', op=<built-in function xor>, output='rhf')
# Gate(a='y21', b='x21', op=<built-in function xor>, output='qfh')
# Gate(a='y25', b='x25', op=<built-in function and_>, output='mnt')
